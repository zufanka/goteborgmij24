# %%
import pandas as pd

# %%
firms = pd.read_csv("data/law_firms.csv")
keep = ["ID", "Original Name", "Interest Represented","Web Site URL",
       "Registration Date","Calculated Cost (€)","Members Fte",
        "Activity Relevant Comm","Networking","Goals","Info Members"]

firms = firms[keep]
firms.columns = ["id", "lawfirm_name", "interests_represented","web",
       "registration_date","lobby_costs","lobby_fte",
        "activity","networking","goals","info_members"]

firms.to_csv("data/law_firms-clean.csv")
firms.sample(4)
# Out:
#         id                                       lawfirm_name  \
# 31  201008                                      MARYSE COPPET
# 22  199439                 Freshfields Bruckhaus Deringer LLP
# 19  199213  BLOMSTEIN Partnerschaft von Rechtsanwälten mbB...
# 34  201177                                        Hirsbrunner
#
#                   interests_represented                                   web  \
# 31  Advances interests of their clients           http://www.marysecoppet.com
# 22  Advances interests of their clients  http://www.freshfields.com/en/global
# 19  Advances interests of their clients            https://www.blomstein.com/
# 34  Advances interests of their clients                  www.shirsbrunner.com
#
#     registration_date lobby_costs  lobby_fte  \
# 31   2015-7-15, 22:00     155,000        2.5
# 22  2015-10-21, 22:00     570,000        5.0
# 19    2022-6-7, 22:00      20,000        0.3
# 34   2022-2-21, 23:00      10,000        0.5
#
#                                              activity  \
# 31  Ambassadrice du Pacte Climatique de l'UE\nPart...
# 22  We work with our lawyers globally to share ins...
# 19  Wir haben unsere Mandanten bei dem Entwurf ein...
# 34  - Teilnahme an Konferenzen und Tagungen\r\n- B...
#
#                                            networking  \
# 31  Mouvement Outre Mer. https://www.helloasso.com...
# 22  American Chamber of Commerce to the European U...
# 19  Bundesverband der Deutschen Sicherheits- und V...
# 34  https://www.rak-dus.de\r\nhttps://www.baliebru...
#
#                                                 goals  \
# 31  Cabinet d'avocats dont le domaine d'activité e...
# 22  We are a global law firm with a long-standing ...
# 19  BLOMSTEIN ist eine  Rechtsanwaltskanzlei mit S...
# 34  Beratung von Unternehmen, Verbänden und öffent...
#
#                                          info_members
# 31                                                NaN
# 22  While Freshfields has 22 people engaged in act...
# 19  1 Person 5% (Associate)\n2 Person 5% (Associat...
# 34                                                NaN

# %%
clients = pd.read_csv("data/clients.csv")
keep = ["State ID", "Client ID", "Customers - Client → Name","Proposal",
       "Money Range - Revenue Range → Min","Money Range - Revenue Range → Max"]

clients.head()
clients = clients[keep]
clients.columns = ["lawfirm_id", "client_id", "client_name" ,"proposal", "revenue_min", "revenue_max"]
clients["revenue_min"] = pd.to_numeric(clients["revenue_min"].str.replace(",",""))
clients["revenue_max"] = pd.to_numeric(clients["revenue_max"].str.replace(",",""))
clients.to_csv("data/clients-clean.csv")
clients.sample(4)
# Out:
#      lawfirm_id  client_id                                        client_name  \
# 145      204464      15059                                       aegis europe
# 124      204336      16805                    consumer technology association
# 140      207080      17593  sitcpla (sindicato independiente de tripulante...
# 18       194049      15274                             world shipping council
#
#                                               proposal  revenue_min  \
# 145                          Trade Defence Instruments          NaN
# 124                                       AI Act, ESPR      50000.0
# 140  Council Directive 79/7/EEC of 19 December 1978...      25000.0
# 18   Commission review of EU consortia block exemption     300000.0
#
#      revenue_max
# 145        10000
# 124        99999
# 140        49999
# 18        399999

# %%
merged = pd.merge(firms, clients, left_on="id", right_on="lawfirm_id")
